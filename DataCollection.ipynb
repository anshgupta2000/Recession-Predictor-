# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
# Out:
# Mounted at /content/gdrive

# %%
#Getting the data
#Yield Curve Data

#Scraping this data from the URL

url = "https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=all&page={}"

all_df = []
for page in range(0, 28):  
    all_df.append(pd.read_html(url.format(page))[0])

yc_df = pd.concat(all_df).reset_index(drop=True)
yc_df
# Out:
#             Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0     01/02/1990    NaN    NaN                   NaN                    NaN
# 1     01/03/1990    NaN    NaN                   NaN                    NaN
# 2     01/04/1990    NaN    NaN                   NaN                    NaN
# 3     01/05/1990    NaN    NaN                   NaN                    NaN
# 4     01/08/1990    NaN    NaN                   NaN                    NaN
# ...          ...    ...    ...                   ...                    ...
# 8133  07/05/2022    NaN    NaN                   NaN                    NaN
# 8134  07/06/2022    NaN    NaN                   NaN                    NaN
# 8135  07/07/2022    NaN    NaN                   NaN                    NaN
# 8136  07/08/2022    NaN    NaN                   NaN                    NaN
# 8137  07/11/2022    NaN    NaN                   NaN                    NaN
#
# ...

# %%
#Consumer Confidence Index Data 
cci_df = pd.read_csv ('/content/gdrive/MyDrive/Recession Predictor Project/Data/Consumer Confidence Index Data/Consumer Confidence Index Data (1960 - 2022 May).csv')
cci_df.head()
# Out:
#   LOCATION INDICATOR   SUBJECT    MEASURE FREQUENCY     TIME   Value  \
# 0      USA       CCI  AMPLITUD  LTRENDIDX         M  1960-01  101.68
# 1      USA       CCI  AMPLITUD  LTRENDIDX         M  1960-02  101.40
# 2      USA       CCI  AMPLITUD  LTRENDIDX         M  1960-03  101.16
# 3      USA       CCI  AMPLITUD  LTRENDIDX         M  1960-04  101.03
# 4      USA       CCI  AMPLITUD  LTRENDIDX         M  1960-05  101.06
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#Effective Federal Funds Rate Data
fedfunds_df = pd.read_csv ('/content/gdrive/MyDrive/Recession Predictor Project/Data/Effective Federal Funds Rate Data/FEDFUNDS (1954 - 2022).csv')
fedfunds_df.head()
# Out:
#          DATE  FEDFUNDS
# 0  1954-07-01      0.80
# 1  1954-08-01      1.22
# 2  1954-09-01      1.07
# 3  1954-10-01      0.85
# 4  1954-11-01      0.83

# %%
#Inflation Rate/Consumer Price Index Data
inflation_cpi_df = pd.read_excel('/content/gdrive/MyDrive/Recession Predictor Project/Data/Inflation_CPI Data /Inflation_CPI Data for whole US.xlsx')

inflation_cpi_df
# Out:
#       Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   1947.0   21.480   21.620   22.000   22.000   21.950   22.080   22.230
# 1   1948.0   23.680   23.670   23.500   23.820   24.010   24.150   24.400
# 2   1949.0   24.010   23.910   23.910   23.920   23.910   23.920   23.700
# 3   1950.0   23.510   23.610   23.640   23.650   23.770   23.880   24.070
# 4   1951.0   25.380   25.830   25.880   25.920   25.990   25.930   25.910
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 71  2018.0  248.743  249.439  249.581  250.146  250.779  251.118  251.323
# 72  2019.0  252.470  253.135  254.273  255.163  255.325  255.361  255.900
# 73  2020.0  258.682  259.007  258.165  256.094  255.944  257.217  258.543
# 74  2021.0  262.200  263.346  265.028  266.727  268.599  270.955  272.184
# 75  2022.0  281.933  284.182  287.708  288.663  291.474      NaN      NaN
#
#         Aug      Sep      Oct      Nov      Dec  Annual  HALF1  HALF2
# ...

# %%
#Market Capitalization to GDP Ratio Data (Buffett Indicator)
buffett_df = pd.read_csv ('/content/gdrive/MyDrive/Recession Predictor Project/Data/Market Cap to GDP Ratio (Buffett Indicator)/fredgraph.csv')
buffett_df.head()
# Out:
#          DATE  WILL5000INDFC_NBD20071001_GDP_NBD20071001
# 0  1971-01-01                                   0.254315
# 1  1971-04-01                                   0.262771
# 2  1971-07-01                                   0.252699
# 3  1971-10-01                                   0.250019
# 4  1972-01-01                                   0.269344

# %%
#Unemployment Rate Data
unrate_df = pd.read_csv ('/content/gdrive/MyDrive/Recession Predictor Project/Data/Unemployment Rate Data/UNRATE.csv')
unrate_df.head()
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5
